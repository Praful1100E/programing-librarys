# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x_data = np.random.random(50)*100
y_data = np.random.random(50)*100
plt.scatter(x_data,y_data)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
x_data = np.random.random(50)*100
y_data = np.random.random(50)*100
plt.scatter(x_data,y_data,c='r',s=150,marker='*',alpha=0.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
x_data = np.random.random(50)*100
y_data = np.random.random(50)*100
plt.scatter(x_data,y_data,c='r',s=150,marker='*',alpha=0.3)
plt.show()

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
# print(len(weight))
plt.plot(years,weight)

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
# print(len(weight))
plt.scatter(years,weight)
plt.show()

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
# print(len(weight))
plt.scatter(years,weight,color='r')
plt.show()

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
# print(len(weight))
plt.plot(years,weight,lw=10)
plt.show()

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
# print(len(weight))
plt.plot(years,weight,linestyle='--')
plt.show()

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
plt.plot(years,weight,"r--")
plt.show()

# %%
years=[2006 +x for x in range(16)]
weight =[32,34,5,6,53,54,34,23,43,23,21,12,45,56,76,54]
plt.plot(years,weight,color='r')
plt.show()

# %%
X = [10,20,10,30,30,20,20]
plt.title("Programming")
Y = ["C","Python","c","Rust","Go","Java","JavaScript"]
plt.bar(Y,X)
# Out:
# <BarContainer object of 7 artists>

# %%
X = [10,20,10,30,30,20,20]
plt.title("Programming")
Y = ["C","Python","c","Rust","Go","Java","JavaScript"]
plt.bar(Y,X,color='r',align='edge',width=0.4,edgecolor='green',lw=9)
plt.show()

# %%
age = np.random(30,3.5)
plt.hist(ages)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 age = np.random(30,3.5)
#       2 plt.hist(ages)
#       3 plt.show()
#
# TypeError: 'module' object is not callable
